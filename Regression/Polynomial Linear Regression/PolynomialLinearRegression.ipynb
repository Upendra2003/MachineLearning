# %% [markdown]
# # Polynomial Linear Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Position_Salaries.csv')
df.head()
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
X=df.iloc[:,1:-1].values
y=df.iloc[:,-1].values

# %%
y
# Out:
# array([  45000,   50000,   60000,   80000,  110000,  150000,  200000,
#         300000,  500000, 1000000], dtype=int64)

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X,y)
plt.scatter(X,y)
plt.plot(X,regressor.predict(X))
plt.show()

# %% [markdown]
# ### Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=5) # By increasing the degree we get accurate result
X_poly = poly_reg.fit_transform(X)
lin_reg_model=LinearRegression()
lin_reg_model.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
plt.scatter(X,y,color='red')
plt.plot(X,lin_reg_model.predict(X_poly),color='blue')
plt.show()

# %%
regressor.predict([[6.5]])
# Out:
# array([330378.78787879])

# %%
lin_reg_model.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([174878.07765177])
